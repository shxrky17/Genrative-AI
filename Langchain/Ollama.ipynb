# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings=(
    OllamaEmbeddings(model="gemma:2b")
)
# Out:
# C:\Users\chafl\AppData\Local\Temp\ipykernel_7980\986187925.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma:2b")

# %%
r1=embeddings.embed_documents(
    [
        "yehllo",
        "hello",
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 r1=embeddings.embed_documents(
#       2     [
#       3         "yehllo",
#       4         "hello",
#       5     ]
#       6 )
#
# File c:\Users\chafl\miniconda3\envs\hello\Lib\site-packages\langchain_community\embeddings\ollama.py:214, in OllamaEmbeddings.embed_documents(self, texts)
#     205 """Embed documents using an Ollama deployed embedding model.
#     206
#     207 Args:
#    (...)
#     211     List of embeddings, one for each text.
#     212 """
#     213 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 214 embeddings = self._embed(instruction_pairs)
#     215 return embeddings
#
# File c:\Users\chafl\miniconda3\envs\hello\Lib\site-packages\langchain_community\embeddings\ollama.py:202, in OllamaEmbeddings._embed(self, input)
#     200 else:
#     201     iter_ = input
# --> 202 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File c:\Users\chafl\miniconda3\envs\hello\Lib\site-packages\langchain_community\embeddings\ollama.py:176, in OllamaEmbeddings._process_emb_response(self, input)
#     173     raise ValueError(f"Error raised by inference endpoint: {e}")
#     175 if res.status_code != 200:
# --> 176     raise ValueError(
#     177         "Error raised by inference API HTTP code: %s, %s"
#     178         % (res.status_code, res.text)
#     179     )
#     180 try:
#     181     t = res.json()
#
# ValueError: Error raised by inference API HTTP code: 404, {"error":"model \"gemma:2b\" not found, try pulling it first"}

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
text="yash is king"
query=embeddings.embed_query(text)

# %%
query
# Out:
# [-0.002062038751319051,
#  0.007905776612460613,
#  0.020225556567311287,
#  -0.03838556632399559,
#  -0.03936672955751419,
#  -0.009809914976358414,
#  0.06464219838380814,
#  -0.041433949023485184,
#  0.0708068460226059,
#  0.031883180141448975,
#  -0.022755727171897888,
#  -0.07008697092533112,
#  -0.007932553067803383,
#  0.003958572633564472,
#  -0.008184093050658703,
#  -0.007827810943126678,
#  0.009293180890381336,
#  -0.024128327146172523,
#  -0.08999379724264145,
#  -0.045754071325063705,
#  -0.01704796776175499,
#  0.04991159588098526,
#  -0.0012562625342980027,
#  0.04929155856370926,
#  -0.03907538205385208,
#  -0.027927309274673462,
#  0.034377556294202805,
#  0.0734521821141243,
#  0.03951568156480789,
#  -0.10469906777143478,
#  -0.027371851727366447,
#  -0.07106149941682816,
#  -0.0034029390662908554,
#  0.05619724467396736,
#  -0.005702338181436062,
#  0.030955255031585693,
#  0.11818413436412811,
#  0.024412158876657486,
#  0.014187060296535492,
#  0.039037927985191345,
#  -0.027508314698934555,
#  -0.0725596621632576,
